# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Datasets/ANZ.csv", index_col=['extraction'], parse_dates=['extraction'])

df1 = pd.DataFrame()

dayavg1 = df.resample('1D').amount.mean()

dayavg1.plot()
plt.show()

dayavg2 = df.resample('2D').amount.mean()
print (dayavg2)

dayavg2.plot()
# Out:
# extraction
# 2018-08-01 00:00:00+00:00    178.734464
# 2018-08-03 00:00:00+00:00    161.427745
# 2018-08-05 00:00:00+00:00    234.747387
# 2018-08-07 00:00:00+00:00    228.141765
# 2018-08-09 00:00:00+00:00    198.737200
# 2018-08-11 00:00:00+00:00     47.200208
# 2018-08-13 00:00:00+00:00    240.326380
# 2018-08-15 00:00:00+00:00    242.885000
# 2018-08-17 00:00:00+00:00    161.313831
# 2018-08-19 00:00:00+00:00    246.601209
# 2018-08-21 00:00:00+00:00    177.357873
# 2018-08-23 00:00:00+00:00    225.214805
# 2018-08-25 00:00:00+00:00     38.355385
# 2018-08-27 00:00:00+00:00    229.490753
# 2018-08-29 00:00:00+00:00    176.412411
# 2018-08-31 00:00:00+00:00    148.791379
# 2018-09-02 00:00:00+00:00    193.050294
# 2018-09-04 00:00:00+00:00    187.418832
# 2018-09-06 00:00:00+00:00    243.961974
# 2018-09-08 00:00:00+00:00     63.037510
# 2018-09-10 00:00:00+00:00    248.782489
# 2018-09-12 00:00:00+00:00    189.139109
# 2018-09-14 00:00:00+00:00    195.646806
# 2018-09-16 00:00:00+00:00    205.909913
# 2018-09-18 00:00:00+00:00    212.621058
# 2018-09-20 00:00:00+00:00    235.429869
# 2018-09-22 00:00:00+00:00     57.213267
# 2018-09-24 00:00:00+00:00    270.719954
# 2018-09-26 00:00:00+00:00    208.312597
# 2018-09-28 00:00:00+00:00    152.977836
# 2018-09-30 00:00:00+00:00    223.149952
# 2018-10-02 00:00:00+00:00    179.717570
# 2018-10-04 00:00:00+00:00    202.712324
# 2018-10-06 00:00:00+00:00     49.901617
# 2018-10-08 00:00:00+00:00    265.436058
# 2018-10-10 00:00:00+00:00    172.684433
# 2018-10-12 00:00:00+00:00    174.567045
# 2018-10-14 00:00:00+00:00    231.271120
# 2018-10-16 00:00:00+00:00    185.139318
# 2018-10-18 00:00:00+00:00    279.704188
# 2018-10-20 00:00:00+00:00     69.267722
# 2018-10-22 00:00:00+00:00    303.159952
# 2018-10-24 00:00:00+00:00    202.710243
# 2018-10-26 00:00:00+00:00    180.481858
# 2018-10-28 00:00:00+00:00    191.784694
# 2018-10-30 00:00:00+00:00    191.432478
# Freq: 2D, Name: amount, dtype: float64
# <AxesSubplot:xlabel='extraction'>

# %%
dayavg7 = df.resample('7D').amount.mean()
print(dayavg7)

df2 = pd.DataFrame()

df2 = dayavg7

df2.plot()
# Out:
# extraction
# 2018-08-01 00:00:00+00:00    203.403261
# 2018-08-08 00:00:00+00:00    162.543736
# 2018-08-15 00:00:00+00:00    205.925694
# 2018-08-22 00:00:00+00:00    166.576091
# 2018-08-29 00:00:00+00:00    176.921348
# 2018-09-05 00:00:00+00:00    183.766826
# 2018-09-12 00:00:00+00:00    205.682798
# 2018-09-19 00:00:00+00:00    184.084821
# 2018-09-26 00:00:00+00:00    194.053992
# 2018-10-03 00:00:00+00:00    170.080839
# 2018-10-10 00:00:00+00:00    195.777345
# 2018-10-17 00:00:00+00:00    204.946852
# 2018-10-24 00:00:00+00:00    197.007375
# 2018-10-31 00:00:00+00:00    155.795248
# Freq: 7D, Name: amount, dtype: float64
# <AxesSubplot:xlabel='extraction'>

# %%
plt.boxplot(df2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a81d25b4a8>,
#   <matplotlib.lines.Line2D at 0x1a81d03e2e8>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a81d3da908>,
#   <matplotlib.lines.Line2D at 0x1a81d7cbb70>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1a81d25b898>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a81d7d9cf8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a81d7d9fd0>],
#  'means': []}

# %%
df3 = pd.DataFrame()
df3 = dayavg2 #checking for outliers in the data

plt.boxplot(df3)
plt.ylabel("Amount")
plt.xticks([1], [''])
# Out:
# ([<matplotlib.axis.XTick at 0x1a81fba2278>], [Text(1, 0, '')])
